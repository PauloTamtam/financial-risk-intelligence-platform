# %%
# Install Kaggle CLI
# !pip install kaggle

# %%
# Check Kaggle version
# !kaggle --version
# Out:
# Kaggle API 1.7.4.5

# %%
# Download competition dataset to specific folder
# !kaggle competitions download -c home-credit-default-risk -p ../data/raw
# Out:
# ...
#   0%|          | 0.00/688M [00:00<?, ?B/s]
#  10%|#         | 69.0M/688M [00:00<00:00, 722MB/s]
#  21%|##        | 143M/688M [00:00<00:00, 728MB/s]
#  32%|###2      | 222M/688M [00:00<00:00, 772MB/s]
#  43%|####3     | 296M/688M [00:00<00:00, 762MB/s]
#  54%|#####3    | 369M/688M [00:00<00:00, 662MB/s]
#  65%|######4   | 445M/688M [00:00<00:00, 701MB/s]
#  75%|#######4  | 514M/688M [00:00<00:00, 614MB/s]
#  84%|########3 | 576M/688M [00:00<00:00, 563MB/s]
#  92%|#########1| 632M/688M [00:01<00:00, 542MB/s]
# 100%|##########| 688M/688M [00:01<00:00, 620MB/s]

# %%
import os
import zipfile

# Kaggle saves the zip inside the folder defined in the download path
zip_path = "../data/raw/home-credit-default-risk.zip"
extract_to = "../data/raw/"

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("Done! Data extracted.")
# Out:
# Done! Data extracted.
